# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score ,classification_report

# %%
data = pd.read_csv('/content/train - train.csv')

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0            842     0          2.2         0   1.0     0.0         7.0
# 1           1021     1          0.5         1   0.0     1.0        53.0
# 2            563     1          0.5         1   2.0     1.0        41.0
# 3            615     1          2.5         0   0.0     0.0        10.0
# 4           1821     1          1.2         0  13.0     1.0        44.0
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0    0.6      188.0      2.0  ...       20.0     756.0  2549.0   9.0   7.0
# 1    0.7      136.0      3.0  ...      905.0    1988.0  2631.0  17.0   3.0
# 2    0.9      145.0      5.0  ...     1263.0    1716.0  2603.0  11.0   2.0
# 3    0.8      131.0      6.0  ...     1216.0    1786.0  2769.0  16.0   8.0
# 4    0.6      141.0      2.0  ...     1208.0    1212.0  1411.0   8.0   2.0
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
data.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim   fc  four_g  int_memory  \
# 1995            794     1          0.5         1  0.0     1.0         2.0
# 1996           1965     1          2.6         1  0.0     0.0        39.0
# 1997           1911     0          0.9         1  1.0     1.0        36.0
# 1998           1512     0          0.9         0  4.0     1.0        46.0
# 1999            510     1          2.0         1  5.0     1.0        45.0
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 1995    0.8      106.0      6.0  ...     1222.0    1890.0   668.0  13.0   4.0
# 1996    0.2      187.0      4.0  ...      915.0    1965.0  2032.0  11.0  10.0
# 1997    0.7      108.0      8.0  ...      868.0    1632.0  3057.0   9.0   1.0
# 1998    0.1      145.0      5.0  ...      336.0     670.0   869.0  18.0  10.0
# 1999    0.9      168.0      6.0  ...      483.0     754.0  3919.0  19.0   4.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             1995 non-null   float64
#  5   four_g         1995 non-null   float64
#  6   int_memory     1995 non-null   float64
#  7   m_dep          1995 non-null   float64
#  8   mobile_wt      1996 non-null   float64
#  9   n_cores        1996 non-null   float64
#  10  pc             1995 non-null   float64
#  11  px_height      1996 non-null   float64
#  12  px_width       1998 non-null   float64
#  13  ram            1998 non-null   float64
#  14  sc_h           1999 non-null   float64
#  15  sc_w           1999 non-null   float64
#  16  talk_time      2000 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               5
# four_g           5
# int_memory       5
# m_dep            5
# mobile_wt        4
# n_cores          4
# pc               5
# px_height        4
# px_width         2
# ram              2
# sc_h             1
# sc_w             1
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
numerical_cols = ['fc', 'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w']
data[numerical_cols] = data[numerical_cols].fillna(data[numerical_cols].mean())
categorical_cols = ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'talk_time', 'three_g', 'touch_screen', 'wifi', 'price_range']
data[categorical_cols] = data[categorical_cols].fillna(data[categorical_cols].mode().iloc[0])

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0               842     0          2.2         0   1.0     0.0         7.0
# 1              1021     1          0.5         1   0.0     1.0        53.0
# 2               563     1          0.5         1   2.0     1.0        41.0
# 3               615     1          2.5         0   0.0     0.0        10.0
# 4              1821     1          1.2         0  13.0     1.0        44.0
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995            794     1          0.5         1   0.0     1.0         2.0
# 1996           1965     1          2.6         1   0.0     0.0        39.0
# 1997           1911     0          0.9         1   1.0     1.0        36.0
# 1998           1512     0          0.9         0   4.0     1.0        46.0
# 1999            510     1          2.0         1   5.0     1.0        45.0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming 'data' is your DataFrame containing numerical features
numerical_cols = ['battery_power', 'clock_speed', 'fc', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time']

scaler = MinMaxScaler()
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])

# %%
data
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789     0         0.68         0  0.052632     0.0
# 1          0.347361     1         0.00         1  0.000000     1.0
# 2          0.041416     1         0.00         1  0.105263     1.0
# 3          0.076152     1         0.80         0  0.000000     0.0
# 4          0.881764     1         0.28         0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725     1         0.00         1  0.000000     1.0
# 1996       0.977956     1         0.84         1  0.000000     0.0
# 1997       0.941884     0         0.16         1  0.052632     1.0
# 1998       0.675351     0         0.16         0  0.210526     1.0
# 1999       0.006012     1         0.60         1  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores  ...  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  ...   0.010204  0.170895
# ...

# %%
x = data.drop(columns=['price_range'])

# %%
x
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789     0         0.68         0  0.052632     0.0
# 1          0.347361     1         0.00         1  0.000000     1.0
# 2          0.041416     1         0.00         1  0.105263     1.0
# 3          0.076152     1         0.80         0  0.000000     0.0
# 4          0.881764     1         0.28         0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725     1         0.00         1  0.000000     1.0
# 1996       0.977956     1         0.84         1  0.000000     0.0
# 1997       0.941884     0         0.16         1  0.052632     1.0
# 1998       0.675351     0         0.16         0  0.210526     1.0
# 1999       0.006012     1         0.60         1  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  0.10   0.010204  0.170895
# ...

# %%
y = data['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 968        0.949900     0         0.00         1  0.368421     0.0
# 240        0.088176     1         0.68         0  0.000000     1.0
# 819        0.490982     0         0.16         1  0.105263     1.0
# 692        0.187041     0         0.24         0  0.105263     0.0
# 420        0.637943     1         0.00         1  0.368421     0.0
# ...             ...   ...          ...       ...       ...     ...
# 1130       0.984636     1         0.56         1  0.105263     0.0
# 1294       0.058784     1         0.00         0  0.052632     1.0
# 860        0.887108     1         0.00         0  0.000000     1.0
# 1459       0.952572     0         0.16         1  0.157895     0.0
# 1126       0.089512     1         0.04         1  0.052632     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 968     0.709677  0.444444   0.925000  0.000000  0.50   0.391327  0.840454
# ...

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9375

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       105
#            1       0.90      0.93      0.92        91
#            2       0.90      0.84      0.87        92
#            3       0.95      0.96      0.96       112
#
#     accuracy                           0.94       400
#    macro avg       0.93      0.93      0.93       400
# weighted avg       0.94      0.94      0.94       400

# %%
X_test_data = pd.read_csv('/content/test - test.csv')
X_test_data= X_test_data.drop(columns=['id'])
X_test_data
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
numerical_cols = ['battery_power', 'clock_speed', 'fc', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time']

scaler = MinMaxScaler()
X_test_data[numerical_cols] = scaler.fit_transform(X_test_data[numerical_cols])
X_test_data
# Out:
#      battery_power  blue  clock_speed  dual_sim        fc  four_g  int_memory  \
# 0         0.362241     1         0.52         1  0.736842       0    0.048387
# 1         0.227485     1         0.00         1  0.210526       1    0.951613
# 2         0.871915     1         0.92         0  0.052632       0    0.403226
# 3         0.697799     0         0.00         1  0.947368       1    0.370968
# 4         0.623082     0         0.36         0  0.578947       1    0.758065
# ..             ...   ...          ...       ...       ...     ...         ...
# 995       0.800534     1         0.56         0  0.000000       1    0.838710
# 996       0.072715     0         0.52         1  0.000000       0    0.177419
# 997       0.456971     0         0.36         0  0.052632       1    0.096774
# 998       0.689126     1         0.00         1  0.000000       0    0.774194
# 999       0.513676     1         0.00         0  0.210526       1    0.532258
#
# ...

# %%
X_test_data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
y_pred_test = model.predict(X_test_data)

# %%
y_pred_test
# Out:
# array([2, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 1, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 0, 3, 1, 0, 3, 3, 3, 0, 1, 0, 1,
#        2, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 1, 2, 1, 2, 1, 0, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 2, 1, 0, 2,
#        2, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 3, 2, 3, 3, 3, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 1, 1, 0, 1,
#        0, 0, 0, 2, 1, 0, 0, 1, 2, 2, 1, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        3, 3, 1, 2, 3, 3, 3, 2, 2, 1, 0, 0, 1, 3, 0, 3, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 3, 1, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 2, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 0, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 3, 0, 0, 3, 2, 3,
# ...

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
